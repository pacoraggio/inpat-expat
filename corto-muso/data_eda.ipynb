# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_data = pd.read_csv('./data/raw/manager_matches.csv')

# %%
df_data[df_data['date'] == df_data['date'].min()]
# Out:
#       game_id        date  season competition_id competition_type  \
# 1618  2229839  2012-08-11    2012            FR1  domestic_league
#
#                                    club                            opponent  \
# 1618  Paris Saint-Germain Football Club  Football Club Lorient-Bretagne Sud
#
#       goals_for  goals_against          manager venue  goal_diff result  \
# 1618          2              2  Carlo Ancelotti  home          0      D
#
#         manager_label
# 1618  Carlo Ancelotti

# %%
df_data.sort_values('date', ascending = True).head(5)
# Out:
#       game_id        date  season competition_id competition_type  \
# 1618  2229839  2012-08-11    2012            FR1  domestic_league
# 897   2244382  2012-08-19    2012            ES1  domestic_league
# 1827  2229846  2012-08-19    2012            FR1  domestic_league
# 0     2251270  2012-08-26    2012            IT1  domestic_league
# 1066  2242834  2012-08-26    2012            ES1  domestic_league
#
#                                    club  \
# 1618  Paris Saint-Germain Football Club
# 897          Real Madrid Club de Fútbol
# 1827  Paris Saint-Germain Football Club
# 0             Associazione Calcio Milan
# 1066         Real Madrid Club de Fútbol
#
#                                        opponent  goals_for  goals_against  \
# 1618         Football Club Lorient-Bretagne Sud          2              2
# 897            Valencia Club de Fútbol S. A. D.          1              1
# 1827                                 AC Ajaccio          0              0
# ...
